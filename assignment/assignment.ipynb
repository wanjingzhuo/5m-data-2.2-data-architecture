# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief

# %% [markdown]
# Write the Python codes for the following questions.

# %% [markdown]
# ## Instructions

# %% [markdown]
# Paste the answer as Python in the answer code section below each question.

# %%
import os
import redis
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
REDIS_HOST = os.getenv('REDIS_HOST')
REDIS_PORT = os.getenv('REDIS_PORT')
REDIS_USERNAME = os.getenv('REDIS_USERNAME')
REDIS_PASSWORD = os.getenv('REDIS_PASSWORD')

import redis

r = redis.Redis(
    host=REDIS_HOST,
    port=REDIS_PORT,
    decode_responses=True,
    username=REDIS_USERNAME,
    password=REDIS_PASSWORD,
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar

# %% [markdown]
# ### Question 1

# %% [markdown]
# Question: How would you create a new hash in Redis to store information about a person, with `john_doe` as the key and include the name (`John Doe`), age (`35`), and email address (`john@email.com`)?

# %% [markdown]
# Answer:

# %%
# Answer Question 1 here
r.hset(
    'john_doe',
    mapping = {
        'name': 'John Doe',
        'age': '35',
        'email': 'john@email.com'
    }
)
# Out:
# 3

# %%
# test the code
print(r.hget('john_doe', 'age'))
print(r.hgetall('john_doe'))
# Out:
# 35
# {'name': 'John Doe', 'age': '35', 'email': 'john@email.com'}

# %% [markdown]
# ### Question 2

# %% [markdown]
# Question: Write Python code to list the first 10 objects (blob name) in the "gcp-public-data-landsat" bucket, along with their sizes.

# %%
from google.cloud import storage

client = storage.Client.create_anonymous_client()
bucket = client.get_bucket("gcp-public-data-landsat")

# %% [markdown]
# Answer:

# %%
# Answer Question 1 here
blobs = bucket.list_blobs()

print(f"First 10 objects in '{bucket.name}':")
for ix, blob in enumerate(blobs):
    print(f'name: {blob.name}, size: {blob.size}')
    if ix == 9:   # stop after 10 entries
        break
# Out:
# First 10 objects in 'gcp-public-data-landsat':
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_ANG.txt, size: 117255
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B1.TIF, size: 75085385
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B10.TIF, size: 40612836
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B11.TIF, size: 39267654
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B2.TIF, size: 76259448
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B3.TIF, size: 76813565
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B4.TIF, size: 78510140
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B5.TIF, size: 80344717
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B6.TIF, size: 76416634
# name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B7.TIF, size: 73888286
